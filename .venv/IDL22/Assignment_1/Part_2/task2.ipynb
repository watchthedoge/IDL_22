# %%
import numpy as np
import keras
from sklearn.model_selection import train_test_split

# Load data
images = np.load('images_75.npy')
labels = np.load('labels_75.npy')

# Normalize images to [0, 1] and add channel dimension
images = images.astype('float32') / 255.0
images = np.expand_dims(images, -1) 

print("Images shape:", images.shape)

# split into train, val and test sets
X_train, X_val_test, y_train, y_val_test = train_test_split(images, labels, test_size=0.2, random_state=42, shuffle=True)
X_val, X_test, y_val, y_test = train_test_split(X_val_test, y_val_test, test_size=0.5, random_state=42)
# Out:
# Images shape: (18000, 75, 75, 1)

# %% [markdown]
# Task 2.1 Classification

# %% [markdown]
# Creating 24 categories (30 minute interval)

# %%
def to_class_label(hours, minutes, interval=30):
    # into 30 minute intervals (interval 0 = 00:00-00:29)
    total_minutes = (hours % 12) * 60 + minutes
    return total_minutes // interval  

# Create class labels for 24 categories (30 minute intervals)
y_train_24 = to_class_label(y_train[:,0], y_train[:,1])
y_val_24 = to_class_label(y_val[:,0], y_val[:,1])
y_test_24 = to_class_label(y_test[:,0], y_test[:,1])

from tensorflow.keras.utils import to_categorical
y_train_24 = to_categorical(y_train_24, 24)
y_val_24 = to_categorical(y_val_24, 24)
y_test_24 = to_categorical(y_test_24, 24)
# Out:
# 2025-10-28 20:36:14.216291: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-28 20:36:14.229854: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761680174.244322 1817126 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761680174.247866 1817126 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761680174.258504 1817126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761680174.258528 1817126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761680174.258530 1817126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761680174.258531 1817126 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-10-28 20:36:14.261789: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def common_sense_err(y_true, y_pred):
    #todo adapt later to compare the original exact time values
    # Convert one-hot encoded predictions to time indices
    y_pred_classes = tf.argmax(y_pred, axis=1)
    y_true_classes = tf.argmax(y_true, axis=1)
    
    # Convert to minutes (multiply by 30 since each class represents 30 minutes)
    pred_minutes = tf.cast(y_pred_classes * 30, tf.float32)
    true_minutes = tf.cast(y_true_classes * 30, tf.float32)
    
    # Calculate absolute difference
    diff = tf.abs(pred_minutes - true_minutes)
    
    # Apply circular correction (if diff > 360, take 720 - diff)
    circular_diff = tf.minimum(diff, 720 - diff)
    
    # Return mean difference in minutes
    return tf.reduce_mean(circular_diff)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def time_classifier(X_train, y_train, X_val, y_val, pixel_size=75, num_categories=24):
    model = models.Sequential([
        layers.Input(shape=(pixel_size, pixel_size, 1)),
        layers.Conv2D(32, (3, 3),padding = 'same', activation='relu'),#, input_shape=(pixel_size, pixel_size, 1)),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        
        layers.Conv2D(64, (3, 3), padding = 'same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)),
        
        layers.Conv2D(128, (3, 3),padding = 'same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D(pool_size=(2, 2)), 
        
        layers.Flatten(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(128, activation='relu'),
        layers.Dropout(0.3),
        layers.Dense(num_categories, activation='softmax')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                loss='categorical_crossentropy',
                metrics=['accuracy'])

    history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_val, y_val))

# %%
# ...existing code...
y_train_24 = y_train_24.astype('float32')
y_val_24   = y_val_24.astype('float32')
y_test_24  = y_test_24.astype('float32')
print("y_train_24 dtype:", y_train_24.dtype)
# ...existing code...
# Out:
# y_train_24 dtype: float32

# %%
time_classifier(X_train, y_train_24, X_val, y_val_24, pixel_size=75, num_categories=24)
# Out:
# 2025-10-28 20:45:09.838906: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 308.99MiB (rounded to 324000000)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-10-28 20:45:09.838930: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1058] BFCAllocator dump for GPU_0_bfc
# 2025-10-28 20:45:09.838938: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (256): 	Total Chunks: 67, Chunks in use: 67. 16.8KiB allocated for chunks. 16.8KiB in use in bin. 3.2KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838941: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (512): 	Total Chunks: 10, Chunks in use: 10. 5.2KiB allocated for chunks. 5.2KiB in use in bin. 4.8KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838944: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1024): 	Total Chunks: 7, Chunks in use: 7. 8.5KiB allocated for chunks. 8.5KiB in use in bin. 7.7KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838948: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2048): 	Total Chunks: 1, Chunks in use: 0. 3.5KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838951: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4096): 	Total Chunks: 2, Chunks in use: 2. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 7.8KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838955: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8192): 	Total Chunks: 3, Chunks in use: 3. 36.0KiB allocated for chunks. 36.0KiB in use in bin. 36.0KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838957: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16384): 	Total Chunks: 2, Chunks in use: 0. 48.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838960: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (32768): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838964: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (65536): 	Total Chunks: 7, Chunks in use: 5. 654.5KiB allocated for chunks. 456.0KiB in use in bin. 450.4KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838968: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (131072): 	Total Chunks: 1, Chunks in use: 1. 128.0KiB allocated for chunks. 128.0KiB in use in bin. 128.0KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838971: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (262144): 	Total Chunks: 3, Chunks in use: 1. 943.0KiB allocated for chunks. 288.0KiB in use in bin. 288.0KiB client-requested in use in bin.
# 2025-10-28 20:45:09.838974: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (524288): 	Total Chunks: 3, Chunks in use: 2. 2.68MiB allocated for chunks. 1.79MiB in use in bin. 1.79MiB client-requested in use in bin.
# 2025-10-28 20:45:09.838976: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1048576): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838979: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838981: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838985: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8388608): 	Total Chunks: 4, Chunks in use: 3. 40.50MiB allocated for chunks. 30.38MiB in use in bin. 30.38MiB client-requested in use in bin.
# 2025-10-28 20:45:09.838988: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16777216): 	Total Chunks: 1, Chunks in use: 0. 18.46MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838991: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838996: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (67108864): 	Total Chunks: 1, Chunks in use: 0. 125.68MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.838998: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (134217728): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.839007: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:45:09.839010: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1081] Bin for 308.99MiB was 256.00MiB, Chunk State:
# 2025-10-28 20:45:09.839013: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1094] Next region of size 198311936
# 2025-10-28 20:45:09.839017: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000000 of size 1280 next 1
# 2025-10-28 20:45:09.839020: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000500 of size 256 next 2
# 2025-10-28 20:45:09.839022: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000600 of size 256 next 3
# 2025-10-28 20:45:09.839024: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000700 of size 256 next 4
# 2025-10-28 20:45:09.839025: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000800 of size 256 next 5
# 2025-10-28 20:45:09.839027: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000900 of size 1280 next 7
# 2025-10-28 20:45:09.839029: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000e00 of size 256 next 8
# 2025-10-28 20:45:09.839030: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000f00 of size 256 next 6
# 2025-10-28 20:45:09.839032: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001000 of size 512 next 9
# 2025-10-28 20:45:09.839034: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001200 of size 256 next 13
# 2025-10-28 20:45:09.839036: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001300 of size 256 next 14
# 2025-10-28 20:45:09.839038: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001400 of size 256 next 12
# 2025-10-28 20:45:09.839040: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001500 of size 256 next 18
# 2025-10-28 20:45:09.839042: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001600 of size 256 next 19
# 2025-10-28 20:45:09.839044: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001700 of size 256 next 15
# 2025-10-28 20:45:09.839045: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada16f1d00 of size 10616832 next 39
# 2025-10-28 20:45:09.839211: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fada2111d00 of size 10616832 next 71
# 2025-10-28 20:45:09.839213: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada2b31d00 of size 10616832 next 70
# 2025-10-28 20:45:09.839215: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada3551d00 of size 10616832 next 103
# 2025-10-28 20:45:09.839217: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fada3f71d00 of size 131785472 next 18446744073709551615
# 2025-10-28 20:45:09.839219: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1119]      Summary of in-use Chunks by size:
# 2025-10-28 20:45:09.839223: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 67 Chunks of size 256 totalling 16.8KiB
# 2025-10-28 20:45:09.839226: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 9 Chunks of size 512 totalling 4.5KiB
# 2025-10-28 20:45:09.839228: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 768 totalling 768B
# 2025-10-28 20:45:09.839230: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 1024 totalling 1.0KiB
# 2025-10-28 20:45:09.839232: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 6 Chunks of size 1280 totalling 7.5KiB
# 2025-10-28 20:45:09.839235: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 4096 totalling 8.0KiB
# 2025-10-28 20:45:09.839237: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 12288 totalling 36.0KiB
# 2025-10-28 20:45:09.839240: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 73728 totalling 144.0KiB
# 2025-10-28 20:45:09.839242: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 79360 totalling 77.5KiB
# 2025-10-28 20:45:09.839245: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 120064 totalling 234.5KiB
# 2025-10-28 20:45:09.839247: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 131072 totalling 128.0KiB
# 2025-10-28 20:45:09.839249: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 294912 totalling 288.0KiB
# 2025-10-28 20:45:09.839251: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 940800 totalling 1.79MiB
# 2025-10-28 20:45:09.839254: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 3 Chunks of size 10616832 totalling 30.38MiB
# 2025-10-28 20:45:09.839256: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1126] Sum Total of in-use chunks: 33.09MiB
# 2025-10-28 20:45:09.839259: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Total bytes in pool: 198311936 memory_limit_: 198311936 available bytes: 0 curr_region_allocation_bytes_: 396623872
# 2025-10-28 20:45:09.839263: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1133] Stats:
# Limit:                       198311936
# InUse:                        34701312
# MaxInUse:                     64524288
# NumAllocs:                         285
# MaxAllocSize:                 19352064
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-10-28 20:45:09.839268: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ***_________******____************__________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 time_classifier(X_train, y_train_24, X_val, y_val_24, pixel_size=75, num_categories=24)
#
# Cell In[15], line 31, in time_classifier(X_train, y_train, X_val, y_val, pixel_size, num_categories)
#       5 model = models.Sequential([
#       6     layers.Input(shape=(pixel_size, pixel_size, 1)),
#       7     layers.Conv2D(32, (3, 3),padding = 'same', activation='relu'),#, input_shape=(pixel_size, pixel_size, 1)),
#    (...)
#      24     layers.Dense(num_categories, activation='softmax')
#      25 ])
#      27 model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
#      28             loss='categorical_crossentropy',
#      29             metrics=['accuracy'])
# ---> 31 history = model.fit(X_train, y_train, epochs=20, batch_size=64, validation_data=(X_val, y_val))
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
model = keras.models.Sequential()
model.add(keras.layers.Flatten(input_shape=[28, 28]))
model.add(keras.layers.Dense(300, activation="relu"))
model.add(keras.layers.Dense(100, activation="relu"))
model.add(keras.layers.Dense(10, activation="softmax"))

model.compile(loss="sparse_categorical_crossentropy",
optimizer="sgd",
metrics=["accuracy"])

history = model.fit(X_train, y_train, epochs=30,validation_data=(X_val, y_val))
# Out:
# /vol/home/s4557093/.conda/envs/tf-gpu/lib/python3.9/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2025-10-28 20:43:36.232196: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate
I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 2 Chunks of size 940800 totalling 1.79MiB
# 2025-10-28 20:43:36.232353: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1122] 1 Chunks of size 10616832 totalling 10.12MiB
# 2025-10-28 20:43:36.232355: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1126] Sum Total of in-use chunks: 12.26MiB
# 2025-10-28 20:43:36.232356: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1128] Total bytes in pool: 198311936 memory_limit_: 198311936 available bytes: 0 curr_region_allocation_bytes_: 396623872
# 2025-10-28 20:43:36.232360: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1133] Stats:
# Limit:                       198311936
# InUse:                        12854272
# MaxInUse:                     33005824
# NumAllocs:                         143
# MaxAllocSize:                 10616832
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2025-10-28 20:43:36.232363: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:512] ***_________******__________________________________________________________________________________
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[13], line 11
#       5 model.add(keras.layers.Dense(10, activation="softmax"))
#       7 model.compile(loss="sparse_categorical_crossentropy",
#       8 optimizer="sgd",
#       9 metrics=["accuracy"])
# ---> 11 history = model.fit(X_train, y_train, epochs=30,validation_data=(X_val, y_val))
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.

# %%
import inspect, numpy as np
import tensorflow as tf
from tensorflow.keras import models, layers, optimizers

# 2) quick build of a simple test model (no BN/Dropout) and print summary
def quick_model(X_train, y_train, X_val, y_val, pixel_size=75, num_categories=24):
    m = models.Sequential([
        layers.Input(shape=(pixel_size,pixel_size,1)),
        layers.Conv2D(32,3,padding='same',activation='relu'),
        layers.MaxPooling2D(),
        layers.Conv2D(64,3,padding='same',activation='relu'),
        layers.MaxPooling2D(),
        layers.Flatten(),
        layers.Dense(128,activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_categories,activation='softmax')
    ])
    m.compile(optimizer=optimizers.Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    history = m.fit(X_train, y_train, epochs=150, batch_size=64, validation_data=(X_val, y_val))

#quick_model(X_train[:100], y_train_24[:100], X_val, y_val_24, pixel_size=75, num_categories=24)
quick_model(X_train, y_train_24, X_val, y_val_24, pixel_size=75, num_categories=24)
# Out:
# 2025-10-28 20:44:09.052046: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:501] Allocator (GPU_0_bfc) ran out of memory trying to allocate 308.99MiB (rounded to 324000000)requested by op _EagerConst
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2025-10-28 20:44:09.052067: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1058] BFCAllocator dump for GPU_0_bfc
# 2025-10-28 20:44:09.052075: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (256): 	Total Chunks: 43, Chunks in use: 43. 10.8KiB allocated for chunks. 10.8KiB in use in bin. 1.2KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052079: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (512): 	Total Chunks: 4, Chunks in use: 4. 2.0KiB allocated for chunks. 2.0KiB in use in bin. 1.8KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052082: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1024): 	Total Chunks: 6, Chunks in use: 5. 7.5KiB allocated for chunks. 6.2KiB in use in bin. 5.6KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052086: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2048): 	Total Chunks: 1, Chunks in use: 0. 3.2KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052089: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4096): 	Total Chunks: 2, Chunks in use: 2. 8.0KiB allocated for chunks. 8.0KiB in use in bin. 7.8KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052093: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8192): 	Total Chunks: 3, Chunks in use: 2. 34.5KiB allocated for chunks. 24.0KiB in use in bin. 24.0KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052096: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16384): 	Total Chunks: 1, Chunks in use: 0. 24.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052099: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (32768): 	Total Chunks: 1, Chunks in use: 0. 36.0KiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052102: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (65536): 	Total Chunks: 6, Chunks in use: 4. 582.5KiB allocated for chunks. 384.0KiB in use in bin. 378.4KiB client-requested in use in bin.
# 2025-10-28 20:44:09.052105: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (131072): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052108: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (262144): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052111: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (524288): 	Total Chunks: 3, Chunks in use: 2. 2.35MiB allocated for chunks. 1.79MiB in use in bin. 1.79MiB client-requested in use in bin.
# 2025-10-28 20:44:09.052114: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (1048576): 	Total Chunks: 1, Chunks in use: 0. 1.45MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052117: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (2097152): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052119: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (4194304): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052123: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (8388608): 	Total Chunks: 3, Chunks in use: 2. 30.38MiB allocated for chunks. 20.25MiB in use in bin. 20.25MiB client-requested in use in bin.
# 2025-10-28 20:44:09.052125: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (16777216): 	Total Chunks: 1, Chunks in use: 0. 18.46MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052128: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (33554432): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052135: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (67108864): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052137: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (134217728): 	Total Chunks: 1, Chunks in use: 0. 135.80MiB allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052140: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1065] Bin (268435456): 	Total Chunks: 0, Chunks in use: 0. 0B allocated for chunks. 0B in use in bin. 0B client-requested in use in bin.
# 2025-10-28 20:44:09.052143: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1081] Bin for 308.99MiB was 256.00MiB, Chunk State:
# 2025-10-28 20:44:09.052145: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1094] Next region of size 198311936
# 2025-10-28 20:44:09.052150: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000000 of size 1280 next 1
# 2025-10-28 20:44:09.052152: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000500 of size 256 next 2
# 2025-10-28 20:44:09.052154: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000600 of size 256 next 3
# 2025-10-28 20:44:09.052155: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000700 of size 256 next 4
# 2025-10-28 20:44:09.052156: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000800 of size 256 next 5
# 2025-10-28 20:44:09.052158: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000900 of size 1280 next 7
# 2025-10-28 20:44:09.052160: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000e00 of size 256 next 8
# 2025-10-28 20:44:09.052161: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0000f00 of size 256 next 6
# 2025-10-28 20:44:09.052163: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001000 of size 512 next 9
# 2025-10-28 20:44:09.052165: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001200 of size 256 next 13
# 2025-10-28 20:44:09.052167: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001300 of size 256 next 14
# 2025-10-28 20:44:09.052168: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001400 of size 256 next 12
# 2025-10-28 20:44:09.052170: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001500 of size 256 next 18
# 2025-10-28 20:44:09.052171: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001600 of size 256 next 19
# 2025-10-28 20:44:09.052173: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001700 of size 256 next 15
# 2025-10-28 20:44:09.052174: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001800 of size 256 next 20
# 2025-10-28 20:44:09.052176: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001900 of size 256 next 23
# 2025-10-28 20:44:09.052178: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001a00 of size 256 next 24
# 2025-10-28 20:44:09.052179: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001b00 of size 256 next 25
# 2025-10-28 20:44:09.052181: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001c00 of size 256 next 26
# 2025-10-28 20:44:09.052182: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001d00 of size 256 next 31
# 2025-10-28 20:44:09.052184: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001e00 of size 256 next
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[14], line 22
#      19     history = m.fit(X_train, y_train, epochs=150, batch_size=64, validation_data=(X_val, y_val))
#      21 #quick_model(X_train[:100], y_train_24[:100], X_val, y_val_24, pixel_size=75, num_categories=24)
# ---> 22 quick_model(X_train, y_train_24, X_val, y_val_24, pixel_size=75, num_categories=24)
#
# Cell In[14], line 19, in quick_model(X_train, y_train, X_val, y_val, pixel_size, num_categories)
#       7 m = models.Sequential([
#       8     layers.Input(shape=(pixel_size,pixel_size,1)),
#       9     layers.Conv2D(32,3,padding='same',activation='relu'),
#    (...)
#      16     layers.Dense(num_categories,activation='softmax')
#      17 ])
#      18 m.compile(optimizer=optimizers.Adam(1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
# ---> 19 history = m.fit(X_train, y_train, epochs=150, batch_size=64, validation_data=(X_val, y_val))
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.conda/envs/tf-gpu/lib/python3.9/site-packages/tensorflow/python/framework/constant_op.py:108, in convert_to_eager_tensor(value, ctx, dtype)
#     106     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     107 ctx.ensure_initialized()
# --> 108 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# InternalError: Failed copying input tensor from /job:localhost/replica:0/task:0/device:CPU:0 to /job:localhost/replica:0/task:0/device:GPU:0 in order to run _EagerConst: Dst tensor is not initialized.
# 38
# 2025-10-28 20:44:09.052185: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0001f00 of size 256 next 36
# 2025-10-28 20:44:09.052188: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002000 of size 256 next 43
# 2025-10-28 20:44:09.052189: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002100 of size 256 next 41
# 2025-10-28 20:44:09.052191: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002200 of size 256 next 42
# 2025-10-28 20:44:09.052192: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002300 of size 256 next 46
# 2025-10-28 20:44:09.052194: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002400 of size 256 next 47
# 2025-10-28 20:44:09.052196: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002500 of size 256 next 48
# 2025-10-28 20:44:09.052197: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002600 of size 1280 next 32
# 2025-10-28 20:44:09.052199: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0002b00 of size 1280 next 33
# 2025-10-28 20:44:09.052201: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003000 of size 256 next 27
# 2025-10-28 20:44:09.052202: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003100 of size 256 next 29
# 2025-10-28 20:44:09.052204: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003200 of size 256 next 30
# 2025-10-28 20:44:09.052205: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003300 of size 256 next 28
# 2025-10-28 20:44:09.052207: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003400 of size 256 next 35
# 2025-10-28 20:44:09.052209: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003500 of size 512 next 34
# 2025-10-28 20:44:09.052210: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003700 of size 256 next 21
# 2025-10-28 20:44:09.052212: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0003800 of size 4096 next 22
# 2025-10-28 20:44:09.052214: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004800 of size 512 next 51
# 2025-10-28 20:44:09.052216: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004a00 of size 256 next 54
# 2025-10-28 20:44:09.052217: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004b00 of size 256 next 50
# 2025-10-28 20:44:09.052219: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004c00 of size 256 next 57
# 2025-10-28 20:44:09.052221: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004d00 of size 256 next 49
# 2025-10-28 20:44:09.052223: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004e00 of size 256 next 58
# 2025-10-28 20:44:09.052224: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0004f00 of size 256 next 61
# 2025-10-28 20:44:09.052226: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fada0005000 of size 3328 next 66
# 2025-10-28 20:44:09.052228: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0005d00 of size 1280 next 67
# 2025-10-28 20:44:09.052229: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006200 of size 256 next 63
# 2025-10-28 20:44:09.052231: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006300 of size 512 next 62
# 2025-10-28 20:44:09.052232: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006500 of size 256 next 64
# 2025-10-28 20:44:09.052234: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006600 of size 256 next 72
# 2025-10-28 20:44:09.052236: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006700 of size 256 next 73
# 2025-10-28 20:44:09.052238: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] InUse at 7fada0006800 of size 256 next 69
# 2025-10-28 20:44:09.052240: I external/local_xla/xla/tsl/framework/bfc_allocator.cc:1114] Free  at 7fada